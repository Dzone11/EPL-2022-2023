# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1.0
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0.0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0.0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0.0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0.0
#
#   pkatt  season             team
# ...

# %%
matches.shape
# Out:
# (1454, 27)

# %%
matches["team"].value_counts() # checking count
# Out:
# Crystal Palace              73
# Wolverhampton Wanderers     73
# Southampton                 73
# Leeds United                73
# Liverpool                   73
# Tottenham Hotspur           73
# Leicester City              73
# Aston Villa                 73
# Brentford                   73
# Everton                     73
# West Ham United             73
# Arsenal                     73
# Manchester City             72
# Chelsea                     72
# Manchester United           72
# Newcastle United            72
# Brighton and Hove Albion    71
# Burnley                     38
# Watford                     38
# Norwich City                38
# Bournemouth                 35
# Nottingham Forest           35
# Fulham                      35
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 55  2022-04-30  12:30  Premier League  Matchweek 35  Sat  Away      W  1.0
# 57  2022-05-07  19:45  Premier League  Matchweek 36  Sat  Home      D  1.0
# 58  2022-05-10  20:00  Premier League  Matchweek 33  Tue  Away      W  2.0
# 60  2022-05-17  19:45  Premier League  Matchweek 37  Tue  Away      W  2.0
# 61  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     40
# Matchweek 27    40
# Matchweek 2     40
# Matchweek 22    40
# Matchweek 23    40
# Matchweek 12    40
# Matchweek 24    40
# Matchweek 26    40
# Matchweek 29    40
# Matchweek 20    40
# Matchweek 30    40
# Matchweek 31    40
# Matchweek 33    40
# Matchweek 34    40
# Matchweek 28    40
# Matchweek 35    40
# Matchweek 7     40
# Matchweek 21    40
# Matchweek 19    40
# Matchweek 10    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 8     40
# Matchweek 18    40
# Matchweek 9     40
# Matchweek 11    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 25    38
# Matchweek 32    36
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %% [markdown]
# # PREDICTORS

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes #creating venue

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes #creating unique codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] =="W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga         opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %% [markdown]
# # ML MODEL

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < "2022-01-01"]

# %%
test = matches[matches["date"] > "2022-01-01"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds= rf.predict(test[predictors]) # passing test data and predictors

# %%
from sklearn.metrics import accuracy_score # checking the accuracy off the model

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.5942698706099815

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction = preds))

# %%
pd.crosstab(index=combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           509  148
# 1           291  134

# %%
from sklearn.metrics import precision_score

# %%
 precision_score(test["target"], preds)
# Out:
# 0.475177304964539

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
 group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W  4.0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W  5.0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W  5.0
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  2.0
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga         opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = "left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# 8  2021-09-25  12:30  Premier League   Matchweek 6  Sat  Away      W  1.0
# 10 2021-10-03  16:30  Premier League   Matchweek 7  Sun  Away      D  2.0
# 11 2021-10-16  15:00  Premier League   Matchweek 8  Sat  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 46 2023-04-15  17:30  Premier League  Matchweek 31  Sat  Home      W  3.0
# 49 2023-04-26  20:00  Premier League  Matchweek 33  Wed  Home      W  4.0
# 50 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 51 2023-05-03  20:00  Premier League  Matchweek 28  Wed  Home      W  3.0
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 36 2023-04-15  15:00  Premier League  Matchweek 31
#                         37 2023-04-22  15:00  Premier League  Matchweek 32
#                         38 2023-04-25  19:30  Premier League  Matchweek 33
#                         39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#
# ...

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 36 2023-04-15  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 37 2023-04-22  15:00  Premier League  Matchweek 32  Sat  Away      L  1.0
# 38 2023-04-25  19:30  Premier League  Matchweek 33  Tue  Home      W  2.0
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L  0.0
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  1.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1380 2023-04-15  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1381 2023-04-22  15:00  Premier League  Matchweek 32  Sat  Away      L  1.0
# 1382 2023-04-25  19:30  Premier League  Matchweek 33  Tue  Home      W  2.0
# 1383 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L  0.0
# 1384 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  1.0
#
# ...

# %% [markdown]
# # Retrainig our machine learining model

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5022421524663677

# %%
combined = combined.merge(matches_rolling [["date","team","opponent","result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 17         0          0 2022-01-23                  Arsenal         Burnley
# 18         1          0 2022-02-10                  Arsenal          Wolves
# 19         1          0 2022-02-19                  Arsenal       Brentford
# 20         1          1 2022-02-24                  Arsenal          Wolves
# 21         1          1 2022-03-06                  Arsenal         Watford
# ...      ...        ...        ...                      ...             ...
# 1380       1          0 2023-04-15  Wolverhampton Wanderers       Brentford
# 1381       0          0 2023-04-22  Wolverhampton Wanderers  Leicester City
# 1382       1          0 2023-04-25  Wolverhampton Wanderers  Crystal Palace
# 1383       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 1384       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
#
#      result
# 17        D
# 18        W
# 19        W
# ...

# %% [markdown]
# # combinig both Home and Away teams

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {"Brighton and Hove Albion": "Brighton",
              "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd",
              "Tottenham Hotspur": "Tottenham",
              "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"} 

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 17         0          0 2022-01-23                  Arsenal         Burnley
# 18         1          0 2022-02-10                  Arsenal          Wolves
# 19         1          0 2022-02-19                  Arsenal       Brentford
# 20         1          1 2022-02-24                  Arsenal          Wolves
# 21         1          1 2022-03-06                  Arsenal         Watford
# ...      ...        ...        ...                      ...             ...
# 1380       1          0 2023-04-15  Wolverhampton Wanderers       Brentford
# 1381       0          0 2023-04-22  Wolverhampton Wanderers  Leicester City
# 1382       1          0 2023-04-25  Wolverhampton Wanderers  Crystal Palace
# 1383       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 1384       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
#
#      result new_team
# 17        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date                   team_x  \
# 0            0            0 2022-01-23                  Arsenal
# 1            1            0 2022-02-10                  Arsenal
# 2            1            0 2022-02-19                  Arsenal
# 3            1            1 2022-02-24                  Arsenal
# 4            1            1 2022-03-06                  Arsenal
# ...        ...          ...        ...                      ...
# 1027         1            0 2023-04-15  Wolverhampton Wanderers
# 1028         0            0 2023-04-22  Wolverhampton Wanderers
# 1029         1            0 2023-04-25  Wolverhampton Wanderers
# 1030         0            0 2023-04-29  Wolverhampton Wanderers
# 1031         1            0 2023-05-06  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0            Burnley        D    Arsenal         0            0
# 1             Wolves        W    Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# 1    95
# 0    84
# Name: actual_x, dtype: int64

# %%
95/179
# Out:
# 0.5307262569832403
